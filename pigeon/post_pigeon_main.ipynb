# %%
from data_processing import *
from plot_functions import *
import argparse
import numpy as np
import pandas as pd
from pymol import cmd


parser = argparse.ArgumentParser(description='Statistical analysis of HDX/MS data for curated RbsR peptides in one or more functional states.')
parser.add_argument('--pm', dest='pm', help="path to pymol structure", required=True)
parser.add_argument('--t', '--table', dest='table', help="path to uptake table", nargs='+', required=True)
parser.add_argument('--r', '--ranges', dest='ranges', help='path to ranges list csv')
parser.add_argument('--e', '--exclude', dest='exclude', action='store_true', help='exclude rather than include rangeslist')
parser.add_argument('--s1', dest='s1', help='first state to compare')
parser.add_argument('--s2', dest='s2', help='second state to compare')
parser.add_argument('--compare', dest='compare', help='dna, ligand, both', nargs=3)
parser.add_argument('--cbarmax', dest='cbarmax', type=float, help='max value for colorbar axis for dDbar')
parser.add_argument('--ldmin', dest='ldmin', type=float, help='in dDbar, minimum difference threshold between ligand/dna states')



args = parser.parse_args(args=['--t', './EcPFK_20230707_BioRep1/peptide_pool_20230724.csv','./EcPFK_20230424/peptide_pool_20230502.csv'
                               '--r', './EcPFK_20230707_BioRep1/ranges_list_e.csv', 
                               '--pm', '../example/2dri_protein.pdb',])

#args.table = ['../example/10-25_rbsb_pool_results-CLEANED.csv']
#args.ranges = ['../example/rangeslist-10-25-select-cleaned.csv']

# %% [markdown]
# # Load the data and creat HDXMSdata object

# %%
tables = ['../example/10-25_rbsb_pool_results-CLEANED.csv']
ranges = ['../example/rangeslist-10-25-select-cleaned.csv']
cleaned = read_hdx_tables(tables, ranges, exclude=False)

tables2 = ['../example/10-18-RbsB_peptide_pool_results-CLEAN.csv']
ranges2 = ['../example/rangeslist-10-18-select-cleaned.csv']
cleaned2 = read_hdx_tables(tables2, ranges2, exclude=False)
# Out:
# rangeslist included !
# rangeslist included !

# %%
cleaned2
# Out:
#       Sequence  Deut Time (sec) Protein State  Start  End      #D    Stddev  \
# 226   VALSATVS              0.0           APO     13   20  0.0000  0.000000
# 227   VALSATVS              0.0           RIB     13   20  0.0000  0.000000
# 1808  VALSATVS             30.0           APO     13   20  1.8860       NaN
# 1809  VALSATVS             30.0           RIB     13   20  1.3920       NaN
# 1810  VALSATVS            120.0           APO     13   20  1.4530       NaN
# ...        ...              ...           ...    ...  ...     ...       ...
# 2059    YPVDLK           3840.0           RIB    286  291  2.2285  0.006364
# 2060    YPVDLK           7680.0           APO    286  291  2.4470  0.056569
# 2061    YPVDLK           7680.0           RIB    286  291  2.3755  0.002121
# 2062    YPVDLK          15360.0           APO    286  291  2.6120  0.073539
# 2063    YPVDLK          15360.0           RIB    286  291  2.5705  0.013435
#
#       #Rep
# 226      1
# 227      1
# 1808     1
# 1809     1
# 1810     1
# ...    ...
# 2059     2
# 2060     2
# 2061     2
# 2062     2
# 2063     2
#
# [2322 rows x 8 columns]

# %%
cleaned
# Out:
#           Sequence  Deut Time (sec) Protein State  Start  End        #D  \
# 60    AVALSATVSANA              0.0           APO     12   23  0.000000
# 61    AVALSATVSANA              0.0           RIB     12   23  0.000000
# 480   AVALSATVSANA             30.0           APO     12   23  0.691333
# 481   AVALSATVSANA             30.0           RIB     12   23  0.608333
# 482   AVALSATVSANA            120.0           APO     12   23  0.980500
# ...            ...              ...           ...    ...  ...       ...
# 2699        PVDLKL           3840.0           RIB    287  292  2.118000
# 2700        PVDLKL           7680.0           APO    287  292  2.227000
# 2701        PVDLKL           7680.0           RIB    287  292  2.290000
# 2702        PVDLKL          15360.0           APO    287  292  2.399000
# 2703        PVDLKL          15360.0           RIB    287  292  2.480000
#
#         Stddev  #Rep
# 60    0.000000     1
# 61    0.000000     1
# 480   0.039273     3
# 481   0.112882     3
# 482   0.088388     2
# ...        ...   ...
# 2699       NaN     1
# 2700       NaN     1
# 2701       NaN     1
# 2702       NaN     1
# 2703       NaN     1
#
# [4032 rows x 8 columns]

# %%
hdxms_data = load_dataframe_to_hdxmsdata(cleaned)
hdxms_data.reindex_peptide_from_pdb(args.pm, first_residue_index=1)

hdxms_data2 = load_dataframe_to_hdxmsdata(cleaned2)
hdxms_data2.reindex_peptide_from_pdb(args.pm, first_residue_index=1)

hdxms_data_list = [hdxms_data, hdxms_data2]
# Out:
# Peptide reindexed with offset -25
# Peptide reindexed with offset -25

# %%
state_i = hdxms_data.states[0]

# %%
hdxms_data.states[0].num_peptides
# Out:
# 224

# %%
hdxms_data2.states[1].num_peptides
# Out:
# 129

# %% [markdown]
# # Make uptake plot

# %%
# make a uptake plot for specific peptide
uptate = UptakePlot([hdxms_data, hdxms_data2], hdxms_data.states[0].peptides[0].sequence, if_plot_fit=True)
fig = uptate.uptakeplot
# Out:
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])

# %%
fig

# %%
# make a uptake plot for all the peptides in hdms_data
uptakes = UptakePlotsCollection(if_plot_fit=True)
uptakes.add_plot_all([hdxms_data, hdxms_data2])
# save all the plots
uptakes.save_plots('/Users/chenlin/Downloads/')
# Out:
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /Users/chenlin/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/chenlin/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/test.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/Users/chenlin/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/test.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # make a uptake plot for all the peptides in hdms_data
#       <a href='vscode-notebook-cell:/Users/chenlin/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/test.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> uptakes = UptakePlotsCollection(if_plot_fit=True)
# ----> <a href='vscode-notebook-cell:/Users/chenlin/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/test.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> uptakes.add_plot_all([hdxms_data, hdxms_data2])
#       <a href='vscode-notebook-cell:/Users/chenlin/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/test.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> # save all the plots
#       <a href='vscode-notebook-cell:/Users/chenlin/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/test.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> uptakes.save_plots('/Users/chenlin/Downloads/')
#
# File ~/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/plot_functions.py:234, in UptakePlotsCollection.add_plot_all(self, hdxms_datas)
#     232 unique_sequences = get_unique_sequences(hdxms_datas)
#     233 for sequence in unique_sequences:
# --> 234     self.add_plot(hdxms_datas, sequence[2])
#
# File ~/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/plot_functions.py:217, in UptakePlotsCollection.add_plot(self, hdxms_datas, sequence)
#     216 def add_plot(self, hdxms_datas, sequence:str):
# --> 217     plot = UptakePlot(hdxms_datas, sequence, if_plot_fit=self.if_plot_fit, color_dict=self.color_dict)
#     218     self.plots.append(plot)
#
# File ~/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/plot_functions.py:103, in UptakePlot.__init__(self, hdxms_datas, sequence, color_dict, if_plot_fit, figure, ax)
#     101 self.ax = ax
#     102 self.title = self.make_title()
# --> 103 self.uptakeplot = self.make_uptakeplot()
#
# File ~/Library/CloudStorage/OneDrive-Personal/research_git/PIGEON/pigeon/plot_functions.py:115, in UptakePlot.make_uptakeplot(self)
#     111     figure, ax = plt.subplots(1, 1, figsize=(9,8))
#     113 scatter_shapes = ['o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X']
# --> 115 sns.lineplot(data=self.hdxms_datas_df,
#     116              x='time', y='deut', hue='state', errorbar='sd',
#     117              err_style='bars', marker='o', linestyle=' ', markersize=18, alpha=0.5,
#     118              ax=ax, palette=self.color_dict)
#     120 # Plot the fit
#     121 if self.if_plot_fit:
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/seaborn/relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/seaborn/relational.py:503, in _LinePlotter.plot(self, ax, kws)
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
# --> 503     ebars = ax.errorbar(
#     504         sub_data["x"], sub_data["y"], **error_param,
#     505         linestyle="", color=line_color, alpha=line_alpha,
#     506         **err_kws
#     507     )
#     509     # Set the capstyle properly on the error bars
#     510     for obj in ebars.get_children():
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:3649, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3644 # This is like
#    3645 #     elow, ehigh = np.broadcast_to(...)
#    3646 #     return dep - elow * ~lolims, dep + ehigh * ~uplims
#    3647 # except that broadcast_to would strip units.
#    3648 low, high = dep + np.row_stack([-(1 - lolims), 1 - uplims]) * err
# -> 3649 barcols.append(lines_func(
#    3650     *apply_mask([indep, low, high], everymask), **eb_lines_style))
#    3651 if self.name == "polar" and dep_axis == "x":
#    3652     for b in barcols:
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1174, in Axes.vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1171 masked_verts[:, 1, 0] = x
#    1172 masked_verts[:, 1, 1] = ymax
# -> 1174 lines = mcoll.LineCollection(masked_verts, colors=colors,
#    1175                              linestyles=linestyles, label=label)
#    1176 self.add_collection(lines, autolim=False)
#    1177 lines._internal_update(kwargs)
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/collections.py:1412, in LineCollection.__init__(self, segments, zorder, **kwargs)
#    1408 kwargs.setdefault('facecolors', 'none')
#    1409 super().__init__(
#    1410     zorder=zorder,
#    1411     **kwargs)
# -> 1412 self.set_segments(segments)
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/collections.py:1418, in LineCollection.set_segments(self, segments)
#    1415 if segments is None:
#    1416     return
# -> 1418 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
#    1419                else mpath.Path(np.asarray(seg, float))
#    1420                for seg in segments]
#    1421 self.stale = True
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/collections.py:1418, in <listcomp>(.0)
#    1415 if segments is None:
#    1416     return
# -> 1418 self._paths = [mpath.Path(seg) if isinstance(seg, np.ma.MaskedArray)
#    1419                else mpath.Path(np.asarray(seg, float))
#    1420                for seg in segments]
#    1421 self.stale = True
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#      99 def __init__(self, vertices, codes=None, _interpolation_steps=1,
#     100              closed=False, readonly=False):
#     101     """
#     102     Create a new path with the given vertices and codes.
#     103
#    (...)
#     127         and codes as read-only arrays.
#     128     """
# --> 129     vertices = _to_unmasked_float_array(vertices)
#     130     _api.check_shape((None, 2), vertices=vertices)
#     132     if codes is not None:
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1333, in _to_unmasked_float_array(x)
#    1328 """
#    1329 Convert a sequence to a float array; if input was a masked array, masked
#    1330 values are converted to nans.
#    1331 """
#    1332 if hasattr(x, 'mask'):
# -> 1333     return np.ma.asarray(x, float).filled(np.nan)
#    1334 else:
#    1335     return np.asarray(x, float)
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/numpy/ma/core.py:8003, in asarray(a, dtype, order)
#    7959 """
#    7960 Convert the input to a masked array of the given data-type.
#    7961
#    (...)
#    8000
#    8001 """
#    8002 order = order or 'C'
# -> 8003 return masked_array(a, dtype=dtype, copy=False, keep_mask=True,
#    8004                     subok=False, order=order)
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/numpy/ma/core.py:2830, in MaskedArray.__new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order)
#    2828 _baseclass = getattr(data, '_baseclass', type(_data))
#    2829 # Check that we're not erasing the mask.
# -> 2830 if isinstance(data, MaskedArray) and (data.shape != _data.shape):
#    2831     copy = True
#    2833 # Here, we copy the _view_, so that we can attach new properties to it
#    2834 # we must never do .view(MaskedConstant), as that would create a new
#    2835 # instance of np.ma.masked, which make identity comparison fail
#
# File ~/opt/anaconda3/envs/openmm/lib/python3.8/site-packages/numpy/ma/core.py:3425, in MaskedArray.shape(self)
#    3423 @property
#    3424 def shape(self):
# -> 3425     return super().shape
#
# KeyboardInterrupt:

# %%
hdxms_data

# %% [markdown]
# # Compare different protein states

# %% [markdown]
# ### make compare object

# %%
# make compare object

state1 = 'APO'
state2 = 'RIB'

state1_list = [i.get_state(state1) for i in hdxms_data_list]
state2_list = [i.get_state(state2) for i in hdxms_data_list]

compare = HDXStatePeptideCompares(state1_list, state2_list)
compare.add_all_compare()

compare1 = HDXStatePeptideCompares([hdxms_data.get_state(state1)], [hdxms_data.get_state(state2)])
compare1.add_all_compare()

# %%
res_compares = HDXStateResidueCompares([i for i in range(1, 320)], state1_list, state2_list)
res_compares.add_all_compare()

create_compare_pymol_plot(res_compares, 0.2, pdb_file=args.pm, save_pdb=True,
                          path='/Users/chenlin/Downloads/')

# %%
compare.peptide_compares[0].compare_info
# Out:
# 'APO-RIB: -13--2 AVALSATVSANA'

# %% [markdown]
# ### plot heatmap

# %%
create_heatmap_compare_tp(compare, 0.6)

# %% [markdown]
# ### plot to pymol

# %%
#create_compare_pymol_plot(compare, colorbar_max=0.05, pdb_file='../example/2dri_protein.pdb', path='/Users/chenlin/Downloads/')

# %% [markdown]
# ### make all the plots and save them

# %%
from itertools import product

items =[state.state_name for state in hdxms_data.states]
combinations = product(['APO'], [x for x in items if x != 'APO'])


OUTDIR = '/Users/chenlin/Downloads/rbsb_output/'
if not os.path.exists(OUTDIR):
    os.makedirs(OUTDIR)

for state1_name, state2_name in combinations:

    state1_list = [i.get_state(state1_name) for i in hdxms_data_list]
    state2_list = [i.get_state(state2_name) for i in hdxms_data_list]

    compare = HDXStatePeptideCompares(state1_list, state2_list)
    compare.add_all_compare()

    heatmap_compare_tp = create_heatmap_compare_tp(compare, 0.5)
    heatmap_compare_tp.savefig(f'{OUTDIR}/{state1}-{state2}-heatmap-tp.png')

    heatmap_compare = create_heatmap_compare(compare, 0.5)
    heatmap_compare.savefig(f'{OUTDIR}/{state1}-{state2}-heatmap.png')

    create_compare_pymol_plot(compare, colorbar_max=0.2, pdb_file=args.pm, path=OUTDIR)



    res_compares = HDXStateResidueCompares([i for i in range(1, 320)], state1_list, state2_list)
    res_compares.add_all_compare()

    create_compare_pymol_plot(res_compares, 0.2, pdb_file=args.pm, path=OUTDIR)

# %%
hdxms_data.
